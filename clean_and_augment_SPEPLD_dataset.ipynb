# %%
# !pip install -U gretel-client
# Out:
# Requirement already satisfied: gretel-client in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (0.8.5)
# Requirement already satisfied: urllib3<1.26,>=1.25.3 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (1.25.9)
# Collecting smart-open<3.0,>=2.1.0
#   Using cached smart_open-2.2.1-py3-none-any.whl
# Requirement already satisfied: pyyaml<=5.4,>=5.3 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (5.3.1)
# Requirement already satisfied: tqdm<5.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (4.62.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (2.8.1)
# Requirement already satisfied: tenacity==6.2.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (6.2.0)
# Requirement already satisfied: click==7.1.2 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (7.1.2)
# Requirement already satisfied: requests==2.25.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (2.25.0)
# Requirement already satisfied: docker==4.4.1 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (4.4.1)
# Requirement already satisfied: tabulate==0.8.9 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from gretel-client) (0.8.9)
# Requirement already satisfied: six>=1.4.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from docker==4.4.1->gretel-client) (1.15.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from docker==4.4.1->gretel-client) (0.59.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from requests==2.25.0->gretel-client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from requests==2.25.0->gretel-client) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from requests==2.25.0->gretel-client) (2.10)
# Requirement already satisfied: boto3 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from smart-open<3.0,>=2.1.0->gretel-client) (1.20.31)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from boto3->smart-open<3.0,>=2.1.0->gretel-client) (0.5.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.31 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from boto3->smart-open<3.0,>=2.1.0->gretel-client) (1.23.31)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/ytadjota/opt/anaconda3/lib/python3.8/site-packages (from boto3->smart-open<3.0,>=2.1.0->gretel-client) (0.10.0)
# Installing collected packages: smart-open
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.2.1
#     Uninstalling smart-open-5.2.1:
#       Successfully uninstalled smart-open-5.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pathy 0.6.1 requires smart-open<6.0.0,>=5.0.0, but you have smart-open 2.2.1 which is incompatible.
# flair 0.7 requires transformers<=3.5.1,>=3.5.0, but you have transformers 4.15.0 which is incompatible.
# Successfully installed smart-open-2.2.1

# %%
import pandas as pd
import numpy as np
from getpass import getpass
from gretel_client import configure_session, ClientConfig, create_project
from gretel_client.helpers import poll
import json
import yaml

# %%
df_students = pd.read_csv("./dataset/student_engagement_level.csv")
df_students.shape
# Out:
# (486, 14)

# %%
df_students = df_students.rename(columns={"# Quiz Reviews before submission": "reviews", 
                   "Assignment 3 lateness indicator": "a1",
                  "Assignment 3 duration to submit (in hours)": "a2",
                  "Average time to submit assignment (in hours)": "a3",
                  "Engagement Level": "engagement"})
df_students = df_students[["reviews", "a1", "a2", "a3", "engagement"]]

# %%
df_students = df_students.assign(gender=np.random.randint(2, size=df_students.index.size))
df_students = df_students.assign(grade=np.random.randint(3, size=df_students.index.size))
df_students.head()
# Out:
#    reviews  a1          a2          a3 engagement  gender  grade
# 0        3   0  116.166667  129.016667          H       0      0
# 1        4   0  217.750000  235.955556          M       1      1
# 2        3   0  260.333333  221.888889          M       1      2
# 3        6   0  271.216667  286.088889          M       0      1
# 4        1   0  260.733333  274.172222          M       1      1

# %%
df_students['engagement'].unique()
# Out:
# array(['H', 'M', 'L'], dtype=object)

# %%
configure_session(ClientConfig(api_key=getpass(prompt="Enter Gretel API key"), 
                               endpoint="https://api.gretel.cloud"))
# key grtu3fe15bbc3de08089a923e94ed388883ccac29ba7227f938d8fb500ad531a9960
# Out:
# Enter Gretel API key········

# %%
project = create_project(display_name="synthetic-data-students")

with open("gretel-config.yml", 'r') as stream:
    config = yaml.safe_load(stream)

# Set the model epochs to 50
config['models'][0]['synthetics']['params']['epochs'] = 60

config['models'][0]['synthetics']['generate']['num_records'] = 10000

print(json.dumps(config, indent=2))
# Out:
# {
#   "schema_version": "1.0",
#   "models": [
#     {
#       "synthetics": {
#         "data_source": "__tmp__",
#         "params": {
#           "epochs": 60,
#           "batch_size": 64,
#           "vocab_size": 20000,
#           "reset_states": false,
#           "learning_rate": 0.01,
#           "rnn_units": 256,
#           "dropout_rate": 0.2,
#           "overwrite": true,
#           "early_stopping": true,
#           "gen_temp": 1.0,
#           "predict_batch_size": 64,
#           "validation_split": false,
#           "dp": false,
#           "dp_noise_multiplier": 0.001,
#           "dp_l2_norm_clip": 5.0,
#           "dp_microbatches": 1,
#           "data_upsample_limit": 10000
#         },
#         "validators": {
#           "in_set_count": 10,
#           "pattern_count": 10
#         },
#         "generate": {
#           "num_records": 10000,
#           "max_invalid": null
#         },
#         "privacy_filters": {
#           "outliers": "medium",
#           "similarity": "medium"
#         }
#       }
#     }
#   ]
# }

# %%
df_students.to_csv('./dataset/clean_student_engagement_level.csv', index=False)
model = project.create_model_obj(model_config=config)
model.data_source = "./dataset/clean_student_engagement_level.csv"
model.submit(upload_data_source=True)
poll(model)

synthetic_df = pd.read_csv(model.get_artifact_link("data_preview"), compression='gzip')
synthetic_df
# Out:
# INFO: Starting poller
# {
#     "uid": "61e11421f26c370a837cd372",
#     "model_name": "oafish-entertaining-wolf",
#     "runner_mode": "cloud",
#     "user_id": "61d90774bff621712241f5de",
#     "project_id": "61e1141e0d7ef82693f93da5",
#     "status_history": {
#         "created": "2022-01-14T06:11:45.787674Z"
#     },
#     "last_modified": "2022-01-14T06:11:45.876602Z",
#     "status": "created",
#     "last_active_hb": null,
#     "duration_minutes": null,
#     "error_msg": null,
#     "error_id": null,
#     "traceback": null,
#     "container_image": "074762682575.dkr.ecr.us-west-2.amazonaws.com/gretelai/synthetics@sha256:2f104a33478cca62f466303cf5750c05d5b4b9b81954821f091f66d5fb36a89b",
#     "model_type": "synthetics",
#     "config": {
#         "schema_version": "1.0",
#         "name": null,
#         "models": [
#             {
#                 "synthetics": {
#                     "data_source": [
#                         "gretel_babe4fcb419043df9f1261f9f54b77bd_clean_student_engagement_level.csv"
#                     ],
#                     "params": {
#                         "field_delimiter": null,
#                         "epochs": 60,
#                         "batch_size": 64,
#                         "vocab_size": 20000,
#                         "reset_states": false,
#                         "learning_rate": 0.01,
#                         "rnn_units": 256,
#                         "dropout_rate": 0.2,
#                         "overwrite": true,
#                         "early_stopping": true,
#                         "gen_temp": 1.0,
#                         "predict_batch_size": 64,
#                         "validation_split": false,
#                         "dp": false,
#                         "dp_noise_multiplier": 0.001,
#                         "dp_l2_norm_clip": 5.0,
#                         "dp_microbatches": 1,
#                         "early_stopping_min_delta": null,
#                         "max_training_time_seconds": 3000,
#                         "field_cluster_size": 20,
#                         "average_record_length_threshold": 250.0,
#                         "data_upsample_limit": 10000
#                     },
#                     "validators": {
#                         "in_set_count": 10,
#                         "pattern_count": 10,
#                         "datetime_formats": "infer"
#                     },
#                     "generate": {
#                         "num_records": 10000,
#                         "max_invalid": null
#                     },
#                     "task": null,
#                     "privacy_filters": {
#                         "outliers": "medium",
#                         "similarity": "medium"
#                     },
#                     "debug": {
#                         "invalid_record_cutoff": 40
#                     }
#                 }
#             }
#         ],
#         "notifications": null,
#         "label_predictors": null
#     },
#     "autouse_config": null,
#     "autouse_handler_id": null
# }
# INFO: Status is pending. A Gretel Cloud worker is being allocated to begin model creation.
# INFO: Status is active. A worker has started creating your model!
# 2022-01-14T06:12:02.490045Z  Starting synthetic model training
# 2022-01-14T06:12:02.492077Z  Loading training data
# 2022-01-14T06:12:02.635880Z  Training data loaded
# {
#     "record_count": 486,
#     "field_count": 7,
#     "upsample_count": 9514
# }
# 2022-01-14T06:12:05.992992Z  Creating semantic validators and preparing training data
# 2022-01-14T06:12:13.811590Z  Beginning ML model training
# 2022-01-14T06:12:21.182653Z  Training epoch completed
# {
#     "epoch": 0,
#     "accuracy": 0.2444,
#     "loss": 3.8884,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:22.132059Z  Training epoch completed
# {
#     "epoch": 1,
#     "accuracy": 0.2471,
#     "loss": 3.4786,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:23.070716Z  Training epoch completed
# {
#     "epoch": 2,
#     "accuracy": 0.2701,
#     "loss": 3.4135,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:24.022386Z  Training epoch completed
# {
#     "epoch": 3,
#     "accuracy": 0.308,
#     "loss": 3.3733,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:24.956569Z  Training epoch completed
# {
#     "epoch": 4,
#     "accuracy": 0.3952,
#     "loss": 2.6673,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:25.914955Z  Training epoch completed
# {
#     "epoch": 5,
#     "accuracy": 0.5205,
#     "loss": 1.8463,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:26.857776Z  Training epoch completed
# {
#     "epoch": 6,
#     "accuracy": 0.5594,
#     "loss": 1.5754,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:27.808559Z  Training epoch completed
# {
#     "epoch": 7,
#     "accuracy": 0.5942,
#     "loss": 1.3907,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:28.768808Z  Training epoch completed
# {
#     "epoch": 8,
#     "accuracy": 0.6336,
#     "loss": 1.2083,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:29.812507Z  Training epoch completed
# {
#     "epoch": 9,
#     "accuracy": 0.6767,
#     "loss": 1.0573,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:30.846184Z  Training epoch completed
# {
#     "epoch": 10,
#     "accuracy": 0.7078,
#     "loss": 0.9443,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:31.802427Z  Training epoch completed
# {
#     "epoch": 11,
#     "accuracy": 0.7331,
#     "loss": 0.8617,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:32.745055Z  Training epoch completed
# {
#     "epoch": 12,
#     "accuracy": 0.7662,
#     "loss": 0.7711,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:33.688069Z  Training epoch completed
# {
#     "epoch": 13,
#     "accuracy": 0.7794,
#     "loss": 0.743,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:34.634239Z  Training epoch completed
# {
#     "epoch": 14,
#     "accuracy": 0.7955,
#     "loss": 0.6932,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:35.581730Z  Training epoch completed
# {
#     "epoch": 15,
#     "accuracy": 0.809,
#     "loss": 0.6586,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:36.532751Z  Training epoch completed
# {
#     "epoch": 16,
#     "accuracy": 0.8206,
#     "loss": 0.6341,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:37.479753Z  Training epoch completed
# {
#     "epoch": 17,
#     "accuracy": 0.8326,
#     "loss": 0.607,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:38.430583Z  Training epoch completed
# {
#     "epoch": 18,
#     "accuracy": 0.8421,
#     "loss": 0.5857,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:39.458539Z  Training epoch completed
# {
#     "epoch": 19,
#     "accuracy": 0.8461,
#     "loss": 0.5825,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:40.484992Z  Training epoch completed
# {
#     "epoch": 20,
#     "accuracy": 0.8566,
#     "loss": 0.5497,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:41.488003Z  Training epoch completed
# {
#     "epoch": 21,
#     "accuracy": 0.8636,
#     "loss": 0.5326,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:42.448155Z  Training epoch completed
# {
#     "epoch": 22,
#     "accuracy": 0.8672,
#     "loss": 0.5197,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:43.395547Z  Training epoch completed
# {
#     "epoch": 23,
#     "accuracy": 0.8697,
#     "loss": 0.5131,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:44.339072Z  Training epoch completed
# {
#     "epoch": 24,
#     "accuracy": 0.8762,
#     "loss": 0.4951,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:45.282089Z  Training epoch completed
# {
#     "epoch": 25,
#     "accuracy": 0.8785,
#     "loss": 0.4894,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:46.226727Z  Training epoch completed
# {
#     "epoch": 26,
#     "accuracy": 0.8807,
#     "loss": 0.481,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:47.190551Z  Training epoch completed
# {
#     "epoch": 27,
#     "accuracy": 0.8834,
#     "loss": 0.4736,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:48.139474Z  Training epoch completed
# {
#     "epoch": 28,
#     "accuracy": 0.884,
#     "loss": 0.4703,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:49.110255Z  Training epoch completed
# {
#     "epoch": 29,
#     "accuracy": 0.886,
#     "loss": 0.4663,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:50.145188Z  Training epoch completed
# {
#     "epoch": 30,
#     "accuracy": 0.8874,
#     "loss": 0.4593,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:51.150349Z  Training epoch completed
# {
#     "epoch": 31,
#     "accuracy": 0.8879,
#     "loss": 0.4557,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:52.093957Z  Training epoch completed
# {
#     "epoch": 32,
#     "accuracy": 0.8893,
#     "loss": 0.4498,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:53.028369Z  Training epoch completed
# {
#     "epoch": 33,
#     "accuracy": 0.8896,
#     "loss": 0.4495,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:53.980788Z  Training epoch completed
# {
#     "epoch": 34,
#     "accuracy": 0.8896,
#     "loss": 0.4466,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:54.894694Z  Training epoch completed
# {
#     "epoch": 35,
#     "accuracy": 0.8885,
#     "loss": 0.4477,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:55.839257Z  Training epoch completed
# {
#     "epoch": 36,
#     "accuracy": 0.8911,
#     "loss": 0.4407,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:56.785063Z  Training epoch completed
# {
#     "epoch": 37,
#     "accuracy": 0.8902,
#     "loss": 0.4402,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:57.732572Z  Training epoch completed
# {
#     "epoch": 38,
#     "accuracy": 0.891,
#     "loss": 0.4388,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:58.712668Z  Training epoch completed
# {
#     "epoch": 39,
#     "accuracy": 0.8908,
#     "loss": 0.4377,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:12:59.741630Z  Training epoch completed
# {
#     "epoch": 40,
#     "accuracy": 0.8923,
#     "loss": 0.4346,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:00.767127Z  Training epoch completed
# {
#     "epoch": 41,
#     "accuracy": 0.8923,
#     "loss": 0.4327,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:01.738328Z  Training epoch completed
# {
#     "epoch": 42,
#     "accuracy": 0.8917,
#     "loss": 0.4318,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:02.649809Z  Training epoch completed
# {
#     "epoch": 43,
#     "accuracy": 0.8915,
#     "loss": 0.4328,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:03.600484Z  Training epoch completed
# {
#     "epoch": 44,
#     "accuracy": 0.8925,
#     "loss": 0.4277,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:04.510080Z  Training epoch completed
# {
#     "epoch": 45,
#     "accuracy": 0.893,
#     "loss": 0.428,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:05.425811Z  Training epoch completed
# {
#     "epoch": 46,
#     "accuracy": 0.8924,
#     "loss": 0.4301,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:06.378149Z  Training epoch completed
# {
#     "epoch": 47,
#     "accuracy": 0.8933,
#     "loss": 0.4262,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:07.323541Z  Training epoch completed
# {
#     "epoch": 48,
#     "accuracy": 0.8929,
#     "loss": 0.4257,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:08.273117Z  Training epoch completed
# {
#     "epoch": 49,
#     "accuracy": 0.8936,
#     "loss": 0.425,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:09.251051Z  Training epoch completed
# {
#     "epoch": 50,
#     "accuracy": 0.8938,
#     "loss": 0.4231,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:10.312423Z  Training epoch completed
# {
#     "epoch": 51,
#     "accuracy": 0.894,
#     "loss": 0.4205,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:11.285166Z  Training epoch completed
# {
#     "epoch": 52,
#     "accuracy": 0.8939,
#     "loss": 0.4206,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:12.203633Z  Training epoch completed
# {
#     "epoch": 53,
#     "accuracy": 0.8944,
#     "loss": 0.4213,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:13.116284Z  Training epoch completed
# {
#     "epoch": 54,
#     "accuracy": 0.8934,
#     "loss": 0.4218,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:14.032291Z  Training epoch completed
# {
#     "epoch": 55,
#     "accuracy": 0.8942,
#     "loss": 0.4218,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:14.976895Z  Training epoch completed
# {
#     "epoch": 56,
#     "accuracy": 0.8946,
#     "loss": 0.4182,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:15.897553Z  Training epoch completed
# {
#     "epoch": 57,
#     "accuracy": 0.8942,
#     "loss": 0.4183,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:16.851057Z  Training epoch completed
# {
#     "epoch": 58,
#     "accuracy": 0.8947,
#     "loss": 0.4176,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:17.768136Z  Training epoch completed
# {
#     "epoch": 59,
#     "accuracy": 0.8946,
#     "loss": 0.4183,
#     "val_accuracy": 0,
#     "val_loss": 0,
#     "batch": 0
# }
# 2022-01-14T06:13:17.783580Z  Generating records
# {
#     "num_records": 10000,
#     "max_invalid": 20000
# }
# 2022-01-14T06:13:22.789217Z  Generation in progress
# {
#     "current_valid_count": 0,
#     "current_invalid_count": 0,
#     "new_valid_count": 0,
#     "new_invalid_count": 0,
#     "completion_percent": 0.0
# }
# 2022-01-14T06:13:27.795673Z  Generation in progress
# {
#     "current_valid_count": 0,
#     "current_invalid_count": 0,
#     "new_valid_count": 0,
#     "new_invalid_count": 0,
#     "completion_percent": 0.0
# }
# 2022-01-14T06:13:32.802056Z  Generation in progress
# {
#     "current_valid_count": 0,
#     "current_invalid_count": 0,
#     "new_valid_count": 0,
#     "new_invalid_count": 0,
#     "completion_percent": 0.0
# }
# 2022-01-14T06:13:37.807977Z  Generation in progress
# {
#     "current_valid_count": 514,
#     "current_invalid_count": 151,
#     "new_valid_count": 514,
#     "new_invalid_count": 151,
#     "completion_percent": 5.14
# }
# 2022-01-14T06:13:42.814223Z  Generation in progress
# {
#     "current_valid_count": 3014,
#     "current_invalid_count": 231,
#     "new_valid_count": 2500,
#     "new_invalid_count": 80,
#     "completion_percent": 30.14
# }
# 2022-01-14T06:13:47.825345Z  Generation in progress
# {
#     "current_valid_count": 5417,
#     "current_invalid_count": 293,
#     "new_valid_count": 2403,
#     "new_invalid_count": 62,
#     "completion_percent": 54.17
# }
# 2022-01-14T06:13:52.841834Z  Generation in progress
# {
#     "current_valid_count": 7879,
#     "current_invalid_count": 366,
#     "new_valid_count": 2462,
#     "new_invalid_count": 73,
#     "completion_percent": 78.79
# }
# 2022-01-14T06:13:57.852068Z  Generation in progress
# {
#     "current_valid_count": 10000,
#     "current_invalid_count": 437,
#     "new_valid_count": 2121,
#     "new_invalid_count": 71,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:13:57.863431Z  Preparing privacy filters
# 2022-01-14T06:13:58.349026Z  Loaded 2 privacy filters
# 2022-01-14T06:13:58.349350Z  Starting privacy filtering
# 2022-01-14T06:13:58.856598Z  Privacy filtering removed 9794 records, generating replacement records
# {
#     "filtered_outliers": 139,
#     "filtered_similarity": 9655
# }
# 2022-01-14T06:14:03.867776Z  Generation in progress
# {
#     "current_valid_count": 694,
#     "current_invalid_count": 55,
#     "new_valid_count": 694,
#     "new_invalid_count": 55,
#     "completion_percent": 7.09
# }
# 2022-01-14T06:14:08.874472Z  Generation in progress
# {
#     "current_valid_count": 1772,
#     "current_invalid_count": 86,
#     "new_valid_count": 1078,
#     "new_invalid_count": 31,
#     "completion_percent": 18.09
# }
# 2022-01-14T06:14:13.878901Z  Generation in progress
# {
#     "current_valid_count": 2833,
#     "current_invalid_count": 111,
#     "new_valid_count": 1061,
#     "new_invalid_count": 25,
#     "completion_percent": 28.93
# }
# 2022-01-14T06:14:18.887759Z  Generation in progress
# {
#     "current_valid_count": 3948,
#     "current_invalid_count": 148,
#     "new_valid_count": 1115,
#     "new_invalid_count": 37,
#     "completion_percent": 40.31
# }
# 2022-01-14T06:14:23.894086Z  Generation in progress
# {
#     "current_valid_count": 4942,
#     "current_invalid_count": 178,
#     "new_valid_count": 994,
#     "new_invalid_count": 30,
#     "completion_percent": 50.46
# }
# 2022-01-14T06:14:28.899005Z  Generation in progress
# {
#     "current_valid_count": 6068,
#     "current_invalid_count": 205,
#     "new_valid_count": 1126,
#     "new_invalid_count": 27,
#     "completion_percent": 61.96
# }
# 2022-01-14T06:14:33.906385Z  Generation in progress
# {
#     "current_valid_count": 7111,
#     "current_invalid_count": 233,
#     "new_valid_count": 1043,
#     "new_invalid_count": 28,
#     "completion_percent": 72.61
# }
# 2022-01-14T06:14:38.910263Z  Generation in progress
# {
#     "current_valid_count": 8247,
#     "current_invalid_count": 265,
#     "new_valid_count": 1136,
#     "new_invalid_count": 32,
#     "completion_percent": 84.2
# }
# 2022-01-14T06:14:43.924037Z  Generation in progress
# {
#     "current_valid_count": 9243,
#     "current_invalid_count": 296,
#     "new_valid_count": 996,
#     "new_invalid_count": 31,
#     "completion_percent": 94.37
# }
# 2022-01-14T06:14:46.927821Z  Generation in progress
# {
#     "current_valid_count": 9794,
#     "current_invalid_count": 305,
#     "new_valid_count": 551,
#     "new_invalid_count": 9,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:14:47.384420Z  Privacy filtering removed 9590 records, generating replacement records
# {
#     "filtered_outliers": 158,
#     "filtered_similarity": 9432
# }
# 2022-01-14T06:14:52.389769Z  Generation in progress
# {
#     "current_valid_count": 640,
#     "current_invalid_count": 64,
#     "new_valid_count": 640,
#     "new_invalid_count": 64,
#     "completion_percent": 6.67
# }
# 2022-01-14T06:14:57.397161Z  Generation in progress
# {
#     "current_valid_count": 1771,
#     "current_invalid_count": 93,
#     "new_valid_count": 1131,
#     "new_invalid_count": 29,
#     "completion_percent": 18.47
# }
# 2022-01-14T06:15:02.402840Z  Generation in progress
# {
#     "current_valid_count": 2781,
#     "current_invalid_count": 126,
#     "new_valid_count": 1010,
#     "new_invalid_count": 33,
#     "completion_percent": 29.0
# }
# 2022-01-14T06:15:07.411878Z  Generation in progress
# {
#     "current_valid_count": 3926,
#     "current_invalid_count": 152,
#     "new_valid_count": 1145,
#     "new_invalid_count": 26,
#     "completion_percent": 40.94
# }
# 2022-01-14T06:15:12.417093Z  Generation in progress
# {
#     "current_valid_count": 4871,
#     "current_invalid_count": 186,
#     "new_valid_count": 945,
#     "new_invalid_count": 34,
#     "completion_percent": 50.79
# }
# 2022-01-14T06:15:17.423035Z  Generation in progress
# {
#     "current_valid_count": 5985,
#     "current_invalid_count": 223,
#     "new_valid_count": 1114,
#     "new_invalid_count": 37,
#     "completion_percent": 62.41
# }
# 2022-01-14T06:15:22.428204Z  Generation in progress
# {
#     "current_valid_count": 6990,
#     "current_invalid_count": 242,
#     "new_valid_count": 1005,
#     "new_invalid_count": 19,
#     "completion_percent": 72.89
# }
# 2022-01-14T06:15:27.434045Z  Generation in progress
# {
#     "current_valid_count": 8104,
#     "current_invalid_count": 280,
#     "new_valid_count": 1114,
#     "new_invalid_count": 38,
#     "completion_percent": 84.5
# }
# 2022-01-14T06:15:32.438277Z  Generation in progress
# {
#     "current_valid_count": 9085,
#     "current_invalid_count": 325,
#     "new_valid_count": 981,
#     "new_invalid_count": 45,
#     "completion_percent": 94.73
# }
# 2022-01-14T06:15:35.441144Z  Generation in progress
# {
#     "current_valid_count": 9590,
#     "current_invalid_count": 342,
#     "new_valid_count": 505,
#     "new_invalid_count": 17,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:15:35.888651Z  Privacy filtering removed 9387 records, generating replacement records
# {
#     "filtered_outliers": 140,
#     "filtered_similarity": 9247
# }
# 2022-01-14T06:15:40.896057Z  Generation in progress
# {
#     "current_valid_count": 588,
#     "current_invalid_count": 52,
#     "new_valid_count": 588,
#     "new_invalid_count": 52,
#     "completion_percent": 6.26
# }
# 2022-01-14T06:15:45.902242Z  Generation in progress
# {
#     "current_valid_count": 1770,
#     "current_invalid_count": 86,
#     "new_valid_count": 1182,
#     "new_invalid_count": 34,
#     "completion_percent": 18.86
# }
# 2022-01-14T06:15:50.906903Z  Generation in progress
# {
#     "current_valid_count": 2759,
#     "current_invalid_count": 121,
#     "new_valid_count": 989,
#     "new_invalid_count": 35,
#     "completion_percent": 29.39
# }
# 2022-01-14T06:15:55.912797Z  Generation in progress
# {
#     "current_valid_count": 3874,
#     "current_invalid_count": 158,
#     "new_valid_count": 1115,
#     "new_invalid_count": 37,
#     "completion_percent": 41.27
# }
# 2022-01-14T06:16:00.916597Z  Generation in progress
# {
#     "current_valid_count": 4873,
#     "current_invalid_count": 184,
#     "new_valid_count": 999,
#     "new_invalid_count": 26,
#     "completion_percent": 51.91
# }
# 2022-01-14T06:16:05.922178Z  Generation in progress
# {
#     "current_valid_count": 6052,
#     "current_invalid_count": 220,
#     "new_valid_count": 1179,
#     "new_invalid_count": 36,
#     "completion_percent": 64.47
# }
# 2022-01-14T06:16:10.926316Z  Generation in progress
# {
#     "current_valid_count": 7049,
#     "current_invalid_count": 247,
#     "new_valid_count": 997,
#     "new_invalid_count": 27,
#     "completion_percent": 75.09
# }
# 2022-01-14T06:16:15.931957Z  Generation in progress
# {
#     "current_valid_count": 8173,
#     "current_invalid_count": 276,
#     "new_valid_count": 1124,
#     "new_invalid_count": 29,
#     "completion_percent": 87.07
# }
# 2022-01-14T06:16:20.937444Z  Generation in progress
# {
#     "current_valid_count": 9170,
#     "current_invalid_count": 302,
#     "new_valid_count": 997,
#     "new_invalid_count": 26,
#     "completion_percent": 97.69
# }
# 2022-01-14T06:16:21.939104Z  Generation in progress
# {
#     "current_valid_count": 9387,
#     "current_invalid_count": 308,
#     "new_valid_count": 217,
#     "new_invalid_count": 6,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:16:22.390767Z  Privacy filtering removed 9192 records, generating replacement records
# {
#     "filtered_outliers": 140,
#     "filtered_similarity": 9052
# }
# 2022-01-14T06:16:27.396992Z  Generation in progress
# {
#     "current_valid_count": 827,
#     "current_invalid_count": 68,
#     "new_valid_count": 827,
#     "new_invalid_count": 68,
#     "completion_percent": 9.0
# }
# 2022-01-14T06:16:32.401639Z  Generation in progress
# {
#     "current_valid_count": 1762,
#     "current_invalid_count": 101,
#     "new_valid_count": 935,
#     "new_invalid_count": 33,
#     "completion_percent": 19.17
# }
# 2022-01-14T06:16:37.406982Z  Generation in progress
# {
#     "current_valid_count": 2933,
#     "current_invalid_count": 139,
#     "new_valid_count": 1171,
#     "new_invalid_count": 38,
#     "completion_percent": 31.91
# }
# 2022-01-14T06:16:42.412076Z  Generation in progress
# {
#     "current_valid_count": 3930,
#     "current_invalid_count": 166,
#     "new_valid_count": 997,
#     "new_invalid_count": 27,
#     "completion_percent": 42.75
# }
# 2022-01-14T06:16:47.417027Z  Generation in progress
# {
#     "current_valid_count": 5056,
#     "current_invalid_count": 192,
#     "new_valid_count": 1126,
#     "new_invalid_count": 26,
#     "completion_percent": 55.0
# }
# 2022-01-14T06:16:52.422476Z  Generation in progress
# {
#     "current_valid_count": 6045,
#     "current_invalid_count": 227,
#     "new_valid_count": 989,
#     "new_invalid_count": 35,
#     "completion_percent": 65.76
# }
# 2022-01-14T06:16:57.428003Z  Generation in progress
# {
#     "current_valid_count": 7172,
#     "current_invalid_count": 253,
#     "new_valid_count": 1127,
#     "new_invalid_count": 26,
#     "completion_percent": 78.02
# }
# 2022-01-14T06:17:02.434258Z  Generation in progress
# {
#     "current_valid_count": 8172,
#     "current_invalid_count": 277,
#     "new_valid_count": 1000,
#     "new_invalid_count": 24,
#     "completion_percent": 88.9
# }
# 2022-01-14T06:17:07.443357Z  Generation in progress
# {
#     "current_valid_count": 9192,
#     "current_invalid_count": 311,
#     "new_valid_count": 1020,
#     "new_invalid_count": 34,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:17:07.918450Z  Privacy filtering removed 9006 records, generating replacement records
# {
#     "filtered_outliers": 143,
#     "filtered_similarity": 8863
# }
# 2022-01-14T06:17:12.925087Z  Generation in progress
# {
#     "current_valid_count": 642,
#     "current_invalid_count": 63,
#     "new_valid_count": 642,
#     "new_invalid_count": 63,
#     "completion_percent": 7.13
# }
# 2022-01-14T06:17:17.931010Z  Generation in progress
# {
#     "current_valid_count": 1813,
#     "current_invalid_count": 96,
#     "new_valid_count": 1171,
#     "new_invalid_count": 33,
#     "completion_percent": 20.13
# }
# 2022-01-14T06:17:22.936201Z  Generation in progress
# {
#     "current_valid_count": 2821,
#     "current_invalid_count": 123,
#     "new_valid_count": 1008,
#     "new_invalid_count": 27,
#     "completion_percent": 31.32
# }
# 2022-01-14T06:17:27.945250Z  Generation in progress
# {
#     "current_valid_count": 3935,
#     "current_invalid_count": 162,
#     "new_valid_count": 1114,
#     "new_invalid_count": 39,
#     "completion_percent": 43.69
# }
# 2022-01-14T06:17:32.951539Z  Generation in progress
# {
#     "current_valid_count": 4931,
#     "current_invalid_count": 198,
#     "new_valid_count": 996,
#     "new_invalid_count": 36,
#     "completion_percent": 54.75
# }
# 2022-01-14T06:17:37.957057Z  Generation in progress
# {
#     "current_valid_count": 6108,
#     "current_invalid_count": 228,
#     "new_valid_count": 1177,
#     "new_invalid_count": 30,
#     "completion_percent": 67.82
# }
# 2022-01-14T06:17:42.962109Z  Generation in progress
# {
#     "current_valid_count": 7100,
#     "current_invalid_count": 260,
#     "new_valid_count": 992,
#     "new_invalid_count": 32,
#     "completion_percent": 78.84
# }
# 2022-01-14T06:17:47.966940Z  Generation in progress
# {
#     "current_valid_count": 8227,
#     "current_invalid_count": 285,
#     "new_valid_count": 1127,
#     "new_invalid_count": 25,
#     "completion_percent": 91.35
# }
# 2022-01-14T06:17:52.972062Z  Generation in progress
# {
#     "current_valid_count": 9006,
#     "current_invalid_count": 296,
#     "new_valid_count": 779,
#     "new_invalid_count": 11,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:17:53.426462Z  Privacy filtering removed 8841 records, generating replacement records
# {
#     "filtered_outliers": 142,
#     "filtered_similarity": 8699
# }
# 2022-01-14T06:17:58.433080Z  Generation in progress
# {
#     "current_valid_count": 709,
#     "current_invalid_count": 59,
#     "new_valid_count": 709,
#     "new_invalid_count": 59,
#     "completion_percent": 8.02
# }
# 2022-01-14T06:18:03.439213Z  Generation in progress
# {
#     "current_valid_count": 1701,
#     "current_invalid_count": 91,
#     "new_valid_count": 992,
#     "new_invalid_count": 32,
#     "completion_percent": 19.24
# }
# 2022-01-14T06:18:08.445259Z  Generation in progress
# {
#     "current_valid_count": 2833,
#     "current_invalid_count": 121,
#     "new_valid_count": 1132,
#     "new_invalid_count": 30,
#     "completion_percent": 32.04
# }
# 2022-01-14T06:18:13.454489Z  Generation in progress
# {
#     "current_valid_count": 3868,
#     "current_invalid_count": 154,
#     "new_valid_count": 1035,
#     "new_invalid_count": 33,
#     "completion_percent": 43.75
# }
# 2022-01-14T06:18:18.461312Z  Generation in progress
# {
#     "current_valid_count": 5003,
#     "current_invalid_count": 182,
#     "new_valid_count": 1135,
#     "new_invalid_count": 28,
#     "completion_percent": 56.59
# }
# 2022-01-14T06:18:23.466932Z  Generation in progress
# {
#     "current_valid_count": 5992,
#     "current_invalid_count": 216,
#     "new_valid_count": 989,
#     "new_invalid_count": 34,
#     "completion_percent": 67.78
# }
# 2022-01-14T06:18:28.473472Z  Generation in progress
# {
#     "current_valid_count": 7117,
#     "current_invalid_count": 244,
#     "new_valid_count": 1125,
#     "new_invalid_count": 28,
#     "completion_percent": 80.5
# }
# 2022-01-14T06:18:33.478540Z  Generation in progress
# {
#     "current_valid_count": 8155,
#     "current_invalid_count": 281,
#     "new_valid_count": 1038,
#     "new_invalid_count": 37,
#     "completion_percent": 92.24
# }
# 2022-01-14T06:18:36.482049Z  Generation in progress
# {
#     "current_valid_count": 8841,
#     "current_invalid_count": 299,
#     "new_valid_count": 686,
#     "new_invalid_count": 18,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:18:36.940164Z  Privacy filtering removed 8667 records, generating replacement records
# {
#     "filtered_outliers": 138,
#     "filtered_similarity": 8529
# }
# 2022-01-14T06:18:41.946141Z  Generation in progress
# {
#     "current_valid_count": 660,
#     "current_invalid_count": 45,
#     "new_valid_count": 660,
#     "new_invalid_count": 45,
#     "completion_percent": 7.62
# }
# 2022-01-14T06:18:46.953442Z  Generation in progress
# {
#     "current_valid_count": 1804,
#     "current_invalid_count": 80,
#     "new_valid_count": 1144,
#     "new_invalid_count": 35,
#     "completion_percent": 20.81
# }
# 2022-01-14T06:18:51.958995Z  Generation in progress
# {
#     "current_valid_count": 2828,
#     "current_invalid_count": 110,
#     "new_valid_count": 1024,
#     "new_invalid_count": 30,
#     "completion_percent": 32.63
# }
# 2022-01-14T06:18:56.965287Z  Generation in progress
# {
#     "current_valid_count": 3952,
#     "current_invalid_count": 144,
#     "new_valid_count": 1124,
#     "new_invalid_count": 34,
#     "completion_percent": 45.6
# }
# 2022-01-14T06:19:01.973659Z  Generation in progress
# {
#     "current_valid_count": 4946,
#     "current_invalid_count": 174,
#     "new_valid_count": 994,
#     "new_invalid_count": 30,
#     "completion_percent": 57.07
# }
# 2022-01-14T06:19:06.979024Z  Generation in progress
# {
#     "current_valid_count": 6073,
#     "current_invalid_count": 199,
#     "new_valid_count": 1127,
#     "new_invalid_count": 25,
#     "completion_percent": 70.07
# }
# 2022-01-14T06:19:11.985063Z  Generation in progress
# {
#     "current_valid_count": 7064,
#     "current_invalid_count": 232,
#     "new_valid_count": 991,
#     "new_invalid_count": 33,
#     "completion_percent": 81.5
# }
# 2022-01-14T06:19:16.990127Z  Generation in progress
# {
#     "current_valid_count": 8233,
#     "current_invalid_count": 261,
#     "new_valid_count": 1169,
#     "new_invalid_count": 29,
#     "completion_percent": 94.99
# }
# 2022-01-14T06:19:19.993946Z  Generation in progress
# {
#     "current_valid_count": 8667,
#     "current_invalid_count": 272,
#     "new_valid_count": 434,
#     "new_invalid_count": 11,
#     "completion_percent": 100.0
# }
# 2022-01-14T06:19:20.533132Z  Privacy filtering removed 8493 records, generating replacement records
# {
#     "filtered_outliers": 147,
#     "filtered_similarity": 8346
# }
# 2022-01-14T06:19:25.541197Z  Generation in progress
# {
#     "current_valid_count": 768,
#     "current_invalid_count": 69,
#     "new_valid_count": 768,
#     "new_invalid_count": 69,
#     "completion_percent": 9.04
# }
# 2022-01-14T06:19:30.545580Z  Generation in progress
# {
#     "current_valid_count": 1827,
#     "current_invalid_count": 93,
#     "new_valid_count": 1059,
#     "new_invalid_count": 24,
#     "completion_percent": 21.51
# }
# 2022-01-14T06:19:35.551728Z  Generation in progress
# {
#     "current_valid_count": 2945,
#     "current_invalid_count": 127,
#     "new_valid_count": 1118,
#     "new_invalid_count": 34,
#     "completion_percent": 34.68
# }
# WARNING:urllib3.connection:Certificate did not match expected hostname: api.gretel.cloud. Certificate: {'subject': ((('countryName', 'FR'),), (('stateOrProvinceName', 'Île-de-France'),), (('organizationName', 'HUB ONE'),), (('organizationalUnitName', 'IT'),), (('commonName', '*.hotspot.hub-one.net'),)), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'Sectigo Limited'),), (('commonName', 'Sectigo RSA Organization Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '3709B25368666F9E56DA71625D345A6A', 'notBefore': 'Sep  8 00:00:00 2021 GMT', 'notAfter': 'Oct  9 23:59:59 2022 GMT', 'subjectAltName': (('DNS', '*.hotspot.hub-one.net'), ('DNS', 'hotspot.hub-one.net')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crt',), 'crlDistributionPoints': ('http://crl.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crl',)}
# WARNING:urllib3.connection:Certificate did not match expected hostname: api.gretel.cloud. Certificate: {'subject': ((('countryName', 'FR'),), (('stateOrProvinceName', 'Île-de-France'),), (('organizationName', 'HUB ONE'),), (('organizationalUnitName', 'IT'),), (('commonName', '*.hotspot.hub-one.net'),)), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'Sectigo Limited'),), (('commonName', 'Sectigo RSA Organization Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '3709B25368666F9E56DA71625D345A6A', 'notBefore': 'Sep  8 00:00:00 2021 GMT', 'notAfter': 'Oct  9 23:59:59 2022 GMT', 'subjectAltName': (('DNS', '*.hotspot.hub-one.net'), ('DNS', 'hotspot.hub-one.net')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crt',), 'crlDistributionPoints': ('http://crl.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crl',)}
# WARNING:urllib3.connection:Certificate did not match expected hostname: api.gretel.cloud. Certificate: {'subject': ((('countryName', 'FR'),), (('stateOrProvinceName', 'Île-de-France'),), (('organizationName', 'HUB ONE'),), (('organizationalUnitName', 'IT'),), (('commonName', '*.hotspot.hub-one.net'),)), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'Sectigo Limited'),), (('commonName', 'Sectigo RSA Organization Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '3709B25368666F9E56DA71625D345A6A', 'notBefore': 'Sep  8 00:00:00 2021 GMT', 'notAfter': 'Oct  9 23:59:59 2022 GMT', 'subjectAltName': (('DNS', '*.hotspot.hub-one.net'), ('DNS', 'hotspot.hub-one.net')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crt',), 'crlDistributionPoints': ('http://crl.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crl',)}
# WARNING:urllib3.connection:Certificate did not match expected hostname: api.gretel.cloud. Certificate: {'subject': ((('countryName', 'FR'),), (('stateOrProvinceName', 'Île-de-France'),), (('organizationName', 'HUB ONE'),), (('organizationalUnitName', 'IT'),), (('commonName', '*.hotspot.hub-one.net'),)), 'issuer': ((('countryName', 'GB'),), (('stateOrProvinceName', 'Greater Manchester'),), (('localityName', 'Salford'),), (('organizationName', 'Sectigo Limited'),), (('commonName', 'Sectigo RSA Organization Validation Secure Server CA'),)), 'version': 3, 'serialNumber': '3709B25368666F9E56DA71625D345A6A', 'notBefore': 'Sep  8 00:00:00 2021 GMT', 'notAfter': 'Oct  9 23:59:59 2022 GMT', 'subjectAltName': (('DNS', '*.hotspot.hub-one.net'), ('DNS', 'hotspot.hub-one.net')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crt',), 'crlDistributionPoints': ('http://crl.sectigo.com/SectigoRSAOrganizationValidationSecureServerCA.crl',)}
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fce343dc790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-9-acf9fe99685f> in <module>
#       3 model.data_source = "./dataset/clean_student_engagement_level.csv"
#       4 model.submit(upload_data_source=True)
# ----> 5 poll(model)
#       6
#       7 synthetic_df = pd.read_csv(model.get_artifact_link("data_preview"), compression='gzip')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/helpers.py in poll(job, wait)
#      44         raise ValueError("Cannot fetch Job polling descriptions")
#      45     sc.print(data=job.print_obj)
# ---> 46     poll_and_print(job, sc, job.runner_mode, descriptions, wait)
#      47
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/cli/common.py in poll_and_print(job, sc, runner, status_strings, wait, callback)
#     428     try:
#     429
# --> 430         for update in job.poll_logs_status(wait=wait, callback=callback):
#     431             if update.transitioned:
#     432                 sc.log.info(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/projects/jobs.py in poll_logs_status(self, wait, callback)
#     321         start = time.time()
#     322         current_status = None
# --> 323         while self._check_predicate(start, wait):
#     324             if callback:
#     325                 callback()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/projects/jobs.py in _check_predicate(self, start, wait)
#     291
#     292     def _check_predicate(self, start: float, wait: int = WAIT_UNTIL_DONE) -> bool:
# --> 293         self._poll_job_endpoint()
#     294         if self.status in END_STATES:
#     295             return False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/projects/jobs.py in _poll_job_endpoint(self)
#     285     def _poll_job_endpoint(self):
#     286         try:
# --> 287             resp = self._do_get_job_details()
#     288         except gretel_client.rest.exceptions.NotFoundException as ex:
#     289             raise self._not_found_error(self) from ex
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/projects/models.py in _do_get_job_details(self)
#     309
#     310     def _do_get_job_details(self):
# --> 311         return self._projects_api.get_model(
#     312             project_id=self.project.name, model_id=self.model_id, expand=[f.LOGS]
#     313         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api_client.py in __call__(self, *args, **kwargs)
#     844
#     845         """
# --> 846         return self.callable(self, *args, **kwargs)
#     847
#     848     def call_with_http_info(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api/projects_api.py in __get_model(self, project_id, model_id, **kwargs)
#    1261             kwargs["project_id"] = project_id
#    1262             kwargs["model_id"] = model_id
# -> 1263             return self.call_with_http_info(**kwargs)
#    1264
#    1265         self.get_model = _Endpoint(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api_client.py in call_with_http_info(self, **kwargs)
#     917             params["header"]["Content-Type"] = header_list
#     918
# --> 919         return self.api_client.call_api(
#     920             self.settings["endpoint_path"],
#     921             self.settings["http_method"],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     426         """
#     427         if not async_req:
# --> 428             return self.__call_api(
#     429                 resource_path,
#     430                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     199         try:
#     200             # perform request and return response
# --> 201             response_data = self.request(
#     202                 method,
#     203                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     480         """Makes the HTTP request using RESTClient."""
#     481         if method == "GET":
# --> 482             return self.rest_client.GET(
#     483                 url,
#     484                 query_params=query_params,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/rest.py in GET(self, url, headers, query_params, _preload_content, _request_timeout)
#     262         _request_timeout=None,
#     263     ):
# --> 264         return self.request(
#     265             "GET",
#     266             url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gretel_client/rest/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     219             # For `GET`, `HEAD`
#     220             else:
# --> 221                 r = self.pool_manager.request(
#     222                     method,
#     223                     url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      73
#      74         if method in self._encode_url_methods:
# ---> 75             return self.request_encode_url(
#      76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     722                 e = ProtocolError("Connection aborted.", e)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     726             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     437
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#     441         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.gretel.cloud', port=443): Max retries exceeded with url: /projects/yvesconst-e5eb8/models/61e11421f26c370a837cd372?expand=logs (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fce343dc790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
synthetic_df.to_csv('./dataset/gen_student_engagement_level.csv', index=False)

# %%
df_students.append(synthetic_df, ignore_index = True).to_csv('./dataset/merged_student_engagement_level.csv', index=False)
